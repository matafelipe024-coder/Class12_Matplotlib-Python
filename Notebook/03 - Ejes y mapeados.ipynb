# %% [markdown]
# # Ejes y mapeados
#
# Como vimos los `DataFrames` automatizan gran parte del trabajo gracias a las etiquetas, pero también podemos configurar manualmente la información de los ejes en caso de trabajar con `listas` o `arrays`:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generamos un array con ahorros de prueba
ahorros = [100, 700, 200, 50, 100, 300]
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio"]

# Gráficamos sin etiquetas
plt.plot(ahorros)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000002922C8239C0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation
# KeyboardInterrupt

# %% [markdown]
# ## Mapeado de texto en los ejes
#
# Para añadir información textual a un eje necesitamos mapear datos en rangos de índices utilizando los métodos `xticks` e `yticks`:

# %%
# Definimos una lista con los meses para el eje horizontal
meses = ['Enero','Febrero','Abril','Marzo','Mayo','Junio']

# %%
# Mapeamos un rango de índices para el eje horizontal
plt.plot(ahorros)
plt.xticks([0,1,2,3,4,5], meses)
# Out:
# ([<matplotlib.axis.XTick at 0x2922d8f6d50>,
#   <matplotlib.axis.XTick at 0x2922d8f65d0>,
#   <matplotlib.axis.XTick at 0x2922d951810>,
#   <matplotlib.axis.XTick at 0x2922d951f90>,
#   <matplotlib.axis.XTick at 0x2922d952710>,
#   <matplotlib.axis.XTick at 0x2922d952e90>],
#  [Text(0, 0, 'Enero'),
#   Text(1, 0, 'Febrero'),
#   Text(2, 0, 'Abril'),
#   Text(3, 0, 'Marzo'),
#   Text(4, 0, 'Mayo'),
#   Text(5, 0, 'Junio')])

# %% [markdown]
# Por cierto, para mostrar en el output de una celda solo el gráfico podemos utilizar específicamente su método `show`:

# %%
ahorros = np.random.randint(100, size=8)
# Definimos una lista con los meses para el eje horizontal
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio', 'Agosto']
plt.plot(ahorros)
print(range(len(meses)))
plt.xticks(range(len(meses)), meses)

plt.show()
# Out:
# range(0, 8)

# %% [markdown]
# Debemos tener en cuenta que aunque tengamos texto mapeado, el verdadero valor del eje X es en realidad un rango incremental de números manejado automáticamente.

# %% [markdown]
# ## Ejes X e Y
#
# Al utilizar un único vector en el método `plot` éste lo toma como los valores del eje Y y genera el X automáticamente a partir de su longitud:

# %%
y = np.random.randint(20, size=[6])
print(y)
plt.plot(y)
plt.show()
# Out:
# [15 14  2 10 10  7]

# %% [markdown]
# Es posible modificar los valores del eje X si los pasamos en otro vector o lista como primer parámetro (siempre que el número de elementos concuerde):

# %%
x = ["A", "B", "C", "D", "E", "F"]
# Gráfica X y Y
plt.plot(x,y)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000002922C8239C0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File c:\Users\fmata\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation

# %% [markdown]
# ## Gráficos invertidos
#
# Algo interesante es que cambiando el orden de los ejes podemos generar un gráfico invertido:

# %%
# Gráfica 
plt.plot(y,x)
plt.show()

# %% [markdown]
# ## Ejemplo curioso
#
# ¿Qué ocurriría si los valores en X también fueran aleatorios?

# %%
x = np.random.randint(20,size=5)
y = np.random.randint(20,size=5)

plt.plot(x,y)
plt.show()

# %% [markdown]
# Como vemos se genera un gráfico muy extraño.
#
# Un gráfico lineal se rige en función del tiempo, eso implica que uno de los ejes es incremental. Al generar valores aleatorios hemos "roto" esa lógica y el resultado es un gráfico donde las líneas se cruzan por todas partes.
